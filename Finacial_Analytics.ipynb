# %% [markdown]
# # Imports Libraries

# %%
import pandas as pd
import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')

# %%
finance_data = pd.read_csv("/content/constituents-financials (1) (1).csv")

# %%
finance_data
# Out:
#     Symbol                    Name                  Sector   Price  \
# 0      MMM              3M Company             Industrials  222.89
# 1      AOS         A.O. Smith Corp             Industrials   60.24
# 2      ABT     Abbott Laboratories             Health Care   56.27
# 3     ABBV             AbbVie Inc.             Health Care  108.48
# 4      ACN           Accenture plc  Information Technology  150.51
# ..     ...                     ...                     ...     ...
# 500    XYL              Xylem Inc.             Industrials   70.24
# 501    YUM         Yum! Brands Inc  Consumer Discretionary   76.30
# 502    ZBH  Zimmer Biomet Holdings             Health Care  115.53
# 503   ZION           Zions Bancorp              Financials   50.71
# 504    ZTS                  Zoetis             Health Care   71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# ...

# %% [markdown]
# # Make a copy of dataset

# %%
df = finance_data.copy()

# %%
df
# Out:
#     Symbol                    Name                  Sector   Price  \
# 0      MMM              3M Company             Industrials  222.89
# 1      AOS         A.O. Smith Corp             Industrials   60.24
# 2      ABT     Abbott Laboratories             Health Care   56.27
# 3     ABBV             AbbVie Inc.             Health Care  108.48
# 4      ACN           Accenture plc  Information Technology  150.51
# ..     ...                     ...                     ...     ...
# 500    XYL              Xylem Inc.             Industrials   70.24
# 501    YUM         Yum! Brands Inc  Consumer Discretionary   76.30
# 502    ZBH  Zimmer Biomet Holdings             Health Care  115.53
# 503   ZION           Zions Bancorp              Financials   50.71
# 504    ZTS                  Zoetis             Health Care   71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# ...

# %% [markdown]
# # Checking Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          505 non-null    object
#  1   Name            505 non-null    object
#  2   Sector          505 non-null    object
#  3   Price           505 non-null    float64
#  4   Price/Earnings  503 non-null    float64
#  5   Dividend Yield  505 non-null    float64
#  6   Earnings/Share  505 non-null    float64
#  7   52 Week Low     505 non-null    float64
#  8   52 Week High    505 non-null    float64
#  9   Market Cap      505 non-null    int64
#  10  EBITDA          505 non-null    float64
#  11  Price/Sales     505 non-null    float64
#  12  Price/Book      497 non-null    float64
#  13  SEC Filings     505 non-null    object
# dtypes: float64(9), int64(1), object(4)
# memory usage: 55.4+ KB

# %%
df.isnull().sum()
# Out:
# Symbol            0
# Name              0
# Sector            0
# Price             0
# Price/Earnings    2
# Dividend Yield    0
# Earnings/Share    0
# 52 Week Low       0
# 52 Week High      0
# Market Cap        0
# EBITDA            0
# Price/Sales       0
# Price/Book        8
# SEC Filings       0
# dtype: int64

# %% [markdown]
# # Data cleaning

# %%
df.drop(['Symbol','SEC Filings'],axis=1, inplace=True)

# %%
df
# Out:
#                        Name                  Sector   Price  Price/Earnings  \
# 0                3M Company             Industrials  222.89           24.31
# 1           A.O. Smith Corp             Industrials   60.24           27.76
# 2       Abbott Laboratories             Health Care   56.27           22.51
# 3               AbbVie Inc.             Health Care  108.48           19.41
# 4             Accenture plc  Information Technology  150.51           25.47
# ..                      ...                     ...     ...             ...
# 500              Xylem Inc.             Industrials   70.24           30.94
# 501         Yum! Brands Inc  Consumer Discretionary   76.30           27.25
# 502  Zimmer Biomet Holdings             Health Care  115.53           14.32
# 503           Zions Bancorp              Financials   50.71           17.73
# 504                  Zoetis             Health Care   71.51           32.80
#
# ...

# %%
df.rename(columns = {'Name':'Company Name', 'Price':'Market Price'}, inplace=True)
df
# Out:
#                Company Name                  Sector  Market Price  \
# 0                3M Company             Industrials        222.89
# 1           A.O. Smith Corp             Industrials         60.24
# 2       Abbott Laboratories             Health Care         56.27
# 3               AbbVie Inc.             Health Care        108.48
# 4             Accenture plc  Information Technology        150.51
# ..                      ...                     ...           ...
# 500              Xylem Inc.             Industrials         70.24
# 501         Yum! Brands Inc  Consumer Discretionary         76.30
# 502  Zimmer Biomet Holdings             Health Care        115.53
# 503           Zions Bancorp              Financials         50.71
# 504                  Zoetis             Health Care         71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company Name    505 non-null    object
#  1   Sector          505 non-null    object
#  2   Market Price    505 non-null    float64
#  3   Price/Earnings  503 non-null    float64
#  4   Dividend Yield  505 non-null    float64
#  5   Earnings/Share  505 non-null    float64
#  6   52 Week Low     505 non-null    float64
#  7   52 Week High    505 non-null    float64
#  8   Market Cap      505 non-null    int64
#  9   EBITDA          505 non-null    float64
#  10  Price/Sales     505 non-null    float64
#  11  Price/Book      497 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 47.5+ KB

# %%
sns.heatmap(df.isna(), yticklabels=False, cbar=False, cmap='BuGn')
# Out:
# <Axes: >

# %%
df[df['Price/Book'].isna()]
# Out:
#              Company Name                  Sector  Market Price  \
# 55            Arconic Inc             Industrials         24.45
# 199       Foot Locker Inc  Consumer Discretionary         45.88
# 225          HCA Holdings             Health Care         95.97
# 292    Marathon Oil Corp.                  Energy         15.68
# 346  Occidental Petroleum                  Energy         68.47
# 358          PepsiCo Inc.        Consumer Staples        110.15
# 450       TransDigm Group             Industrials        283.00
# 460         Union Pacific             Industrials        124.86
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 55            20.21        0.956175           -0.21        31.17
# 199            9.50        2.582795            4.91        77.86
# 225           14.07        1.422764            5.94       106.84
# 292          -32.00        1.224740           -2.65        19.52
# ...

# %%
df['Price/Book'][df['Price/Book'].isna()]
# Out:
# 55    NaN
# 199   NaN
# 225   NaN
# 292   NaN
# 346   NaN
# 358   NaN
# 450   NaN
# 460   NaN
# Name: Price/Book, dtype: float64

# %%
df['Price/Book'][df['Price/Book'].isna()].index
# Out:
# Int64Index([55, 199, 225, 292, 346, 358, 450, 460], dtype='int64')

# %%
df['Price/Book'][df['Price/Book'].isna()] = 1

# %%
df['Price/Book'][df['Price/Book'].isna()]
# Out:
# Series([], Name: Price/Book, dtype: float64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company Name    505 non-null    object
#  1   Sector          505 non-null    object
#  2   Market Price    505 non-null    float64
#  3   Price/Earnings  503 non-null    float64
#  4   Dividend Yield  505 non-null    float64
#  5   Earnings/Share  505 non-null    float64
#  6   52 Week Low     505 non-null    float64
#  7   52 Week High    505 non-null    float64
#  8   Market Cap      505 non-null    int64
#  9   EBITDA          505 non-null    float64
#  10  Price/Sales     505 non-null    float64
#  11  Price/Book      505 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 47.5+ KB

# %%
df['Price/Earnings'].unique()
# Out:
# array([  24.31,   27.76,   22.51,   19.41,   25.47,   31.8 ,   18.22,
#          52.31,   19.54,  187.  ,    9.96,   18.11,   12.24,   27.45,
#          24.22,   32.55,    9.66,   26.03,   19.03,   22.18,   56.59,
#          21.07,   10.65,   13.02,   19.86,   13.26,   31.48,   40.29,
#          18.89,  296.16,   20.38,    9.92,   17.32,   15.  ,   23.22,
#          20.68,   26.23,   12.41,   15.54,   27.61,   13.76,   25.9 ,
#         -21.29,   17.67,   18.78,   42.53,   19.23,   20.8 , -251.53,
#          15.6 ,   16.86,   14.08,   69.74,   17.45,   20.21,   21.05,
#          33.27,   12.14,  -77.07,   29.34,   16.31,   17.97,   22.11,
#         305.56,   20.56,   16.34,   25.12,   16.26,   22.28,   30.43,
#          19.22,   14.3 ,   22.49,   12.29,   27.29,   14.15,   18.05,
#          20.  ,   22.63,   20.83,   15.94,   37.04,   26.  ,   14.32,
#          60.55,   34.09,   14.84,   11.85,   19.44,   17.48,   21.22,
# ...

# %%
df[df['Price/Earnings'].isna()]
# Out:
#        Company Name                  Sector  Market Price  Price/Earnings  \
# 360         Perrigo             Health Care         84.44             NaN
# 430  Tapestry, Inc.  Consumer Discretionary         48.85             NaN
#
#      Dividend Yield  Earnings/Share  52 Week Low  52 Week High   Market Cap  \
# 360        0.731261          -28.01        95.93         63.68  12326379902
# 430        0.000000            2.09        50.71         36.69  14247199374
#
#      EBITDA  Price/Sales  Price/Book
# 360     0.0     3.385007        2.03
# 430     0.0     4.078549        4.35

# %%
df.iloc[360]
# Out:
# Company Name          Perrigo
# Sector            Health Care
# Market Price            84.44
# Price/Earnings            NaN
# Dividend Yield       0.731261
# Earnings/Share         -28.01
# 52 Week Low             95.93
# 52 Week High            63.68
# Market Cap        12326379902
# EBITDA                    0.0
# Price/Sales          3.385007
# Price/Book               2.03
# Name: 360, dtype: object

# %%
df.iloc[430]
# Out:
# Company Name              Tapestry, Inc.
# Sector            Consumer Discretionary
# Market Price                       48.85
# Price/Earnings                       NaN
# Dividend Yield                       0.0
# Earnings/Share                      2.09
# 52 Week Low                        50.71
# 52 Week High                       36.69
# Market Cap                   14247199374
# EBITDA                               0.0
# Price/Sales                     4.078549
# Price/Book                          4.35
# Name: 430, dtype: object

# %%
df['Price/Earnings'][df['Price/Earnings'].isna()] = df['Market Price'] * df['Earnings/Share']

# %%
df['Price/Earnings'][df['Price/Earnings'].isna()]
# Out:
# Series([], Name: Price/Earnings, dtype: float64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company Name    505 non-null    object
#  1   Sector          505 non-null    object
#  2   Market Price    505 non-null    float64
#  3   Price/Earnings  505 non-null    float64
#  4   Dividend Yield  505 non-null    float64
#  5   Earnings/Share  505 non-null    float64
#  6   52 Week Low     505 non-null    float64
#  7   52 Week High    505 non-null    float64
#  8   Market Cap      505 non-null    int64
#  9   EBITDA          505 non-null    float64
#  10  Price/Sales     505 non-null    float64
#  11  Price/Book      505 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 47.5+ KB

# %%
df['Price/Earnings'].unique()
# Out:
# array([   24.31  ,    27.76  ,    22.51  ,    19.41  ,    25.47  ,
#           31.8   ,    18.22  ,    52.31  ,    19.54  ,   187.    ,
#            9.96  ,    18.11  ,    12.24  ,    27.45  ,    24.22  ,
#           32.55  ,     9.66  ,    26.03  ,    19.03  ,    22.18  ,
#           56.59  ,    21.07  ,    10.65  ,    13.02  ,    19.86  ,
#           13.26  ,    31.48  ,    40.29  ,    18.89  ,   296.16  ,
#           20.38  ,     9.92  ,    17.32  ,    15.    ,    23.22  ,
#           20.68  ,    26.23  ,    12.41  ,    15.54  ,    27.61  ,
#           13.76  ,    25.9   ,   -21.29  ,    17.67  ,    18.78  ,
#           42.53  ,    19.23  ,    20.8   ,  -251.53  ,    15.6   ,
#           16.86  ,    14.08  ,    69.74  ,    17.45  ,    20.21  ,
#           21.05  ,    33.27  ,    12.14  ,   -77.07  ,    29.34  ,
#           16.31  ,    17.97  ,    22.11  ,   305.56  ,    20.56  ,
#           16.34  ,    25.12  ,    16.26  ,    22.28  ,    30.43  ,
# ...

# %%
df[df['Price/Earnings'].isna()]
# Out:
# Empty DataFrame
# Columns: [Company Name, Sector, Market Price, Price/Earnings, Dividend Yield, Earnings/Share, 52 Week Low, 52 Week High, Market Cap, EBITDA, Price/Sales, Price/Book]
# Index: []

# %%
df.iloc[360]
# Out:
# Company Name          Perrigo
# Sector            Health Care
# Market Price            84.44
# Price/Earnings     -2365.1644
# Dividend Yield       0.731261
# Earnings/Share         -28.01
# 52 Week Low             95.93
# 52 Week High            63.68
# Market Cap        12326379902
# EBITDA                    0.0
# Price/Sales          3.385007
# Price/Book               2.03
# Name: 360, dtype: object

# %%
df.iloc[430]
# Out:
# Company Name              Tapestry, Inc.
# Sector            Consumer Discretionary
# Market Price                       48.85
# Price/Earnings                  102.0965
# Dividend Yield                       0.0
# Earnings/Share                      2.09
# 52 Week Low                        50.71
# 52 Week High                       36.69
# Market Cap                   14247199374
# EBITDA                               0.0
# Price/Sales                     4.078549
# Price/Book                          4.35
# Name: 430, dtype: object

# %%
df['Price/Earnings'][df['Price/Earnings'].isna()] = df['Market Price'] * df['Earnings/Share']

# %%
df['Price/Earnings'][df['Price/Earnings'].isna()]
# Out:
# Series([], Name: Price/Earnings, dtype: float64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company Name    505 non-null    object
#  1   Sector          505 non-null    object
#  2   Market Price    505 non-null    float64
#  3   Price/Earnings  505 non-null    float64
#  4   Dividend Yield  505 non-null    float64
#  5   Earnings/Share  505 non-null    float64
#  6   52 Week Low     505 non-null    float64
#  7   52 Week High    505 non-null    float64
#  8   Market Cap      505 non-null    int64
#  9   EBITDA          505 non-null    float64
#  10  Price/Sales     505 non-null    float64
#  11  Price/Book      505 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 47.5+ KB

# %% [markdown]
# # Adding new columns

# %%
df['Annual Sales'] = df['Price/Sales'] * df['Market Cap']
df
# Out:
#                Company Name                  Sector  Market Price  \
# 0                3M Company             Industrials        222.89
# 1           A.O. Smith Corp             Industrials         60.24
# 2       Abbott Laboratories             Health Care         56.27
# 3               AbbVie Inc.             Health Care        108.48
# 4             Accenture plc  Information Technology        150.51
# ..                      ...                     ...           ...
# 500              Xylem Inc.             Industrials         70.24
# 501         Yum! Brands Inc  Consumer Discretionary         76.30
# 502  Zimmer Biomet Holdings             Health Care        115.53
# 503           Zions Bancorp              Financials         50.71
# 504                  Zoetis             Health Care         71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# ...

# %%
df.describe(include='all')
# Out:
#        Company Name                  Sector  Market Price  Price/Earnings  \
# count           505                     505    505.000000      505.000000
# unique          505                      11           NaN             NaN
# top      3M Company  Consumer Discretionary           NaN             NaN
# freq              1                      84           NaN             NaN
# mean            NaN                     NaN    103.830634       20.228816
# std             NaN                     NaN    134.427636      114.097279
# min             NaN                     NaN      2.820000    -2365.164400
# 25%             NaN                     NaN     46.250000       15.350000
# 50%             NaN                     NaN     73.920000       19.450000
# 75%             NaN                     NaN    116.540000       25.760000
# max             NaN                     NaN   1806.060000      520.150000
#
#         Dividend Yield  Earnings/Share  52 Week Low  52 Week High  \
# ...

# %%
df['Company Name'].unique()
# Out:
# array(['3M Company', 'A.O. Smith Corp', 'Abbott Laboratories',
#        'AbbVie Inc.', 'Accenture plc', 'Activision Blizzard',
#        'Acuity Brands Inc', 'Adobe Systems Inc', 'Advance Auto Parts',
#        'Advanced Micro Devices Inc', 'AES Corp', 'Aetna Inc',
#        'Affiliated Managers Group Inc', 'AFLAC Inc',
#        'Agilent Technologies Inc', 'Air Products & Chemicals Inc',
#        'Akamai Technologies Inc', 'Alaska Air Group Inc',
#        'Albemarle Corp', 'Alexandria Real Estate Equities Inc',
#        'Alexion Pharmaceuticals', 'Align Technology', 'Allegion',
#        'Allergan, Plc', 'Alliance Data Systems', 'Alliant Energy Corp',
#        'Allstate Corp', 'Alphabet Inc Class A', 'Alphabet Inc Class C',
#        'Altria Group Inc', 'Amazon.com Inc', 'Ameren Corp',
#        'American Airlines Group', 'American Electric Power',
#        'American Express Co', 'American International Group, Inc.',
#        'American Tower Corp A', 'American Water Works Company Inc',
# ...

# %%
for col in df.columns:
    print(col + '\n')
    print(df[col].unique())
    print ('-'*77 + '\n\n')
# Out:
# Company Name
#
# ['3M Company' 'A.O. Smith Corp' 'Abbott Laboratories' 'AbbVie Inc.'
#  'Accenture plc' 'Activision Blizzard' 'Acuity Brands Inc'
#  'Adobe Systems Inc' 'Advance Auto Parts' 'Advanced Micro Devices Inc'
#  'AES Corp' 'Aetna Inc' 'Affiliated Managers Group Inc' 'AFLAC Inc'
#  'Agilent Technologies Inc' 'Air Products & Chemicals Inc'
#  'Akamai Technologies Inc' 'Alaska Air Group Inc' 'Albemarle Corp'
#  'Alexandria Real Estate Equities Inc' 'Alexion Pharmaceuticals'
#  'Align Technology' 'Allegion' 'Allergan, Plc' 'Alliance Data Systems'
#  'Alliant Energy Corp' 'Allstate Corp' 'Alphabet Inc Class A'
#  'Alphabet Inc Class C' 'Altria Group Inc' 'Amazon.com Inc' 'Ameren Corp'
#  'American Airlines Group' 'American Electric Power' 'American Express Co'
#  'American International Group, Inc.' 'American Tower Corp A'
#  'American Water Works Company Inc' 'Ameriprise Financial'
#  'AmerisourceBergen Corp' 'AMETEK Inc' 'Amgen Inc' 'Amphenol Corp'
# ...

# %% [markdown]
# # Save in csv

# %%
os.getcwd()
# Out:
# '/content'

# %%
df.to_csv('Cleaned_finance_data.csv', index=False)
